# %%
# In the following, configure the `Endpoint`, `Masterkey` and `Database` values that point to your instance of Cosmos DB. Then run the cell. This will make these values available to all the notebooks used in this lab.

cosmos_db_endpoint = "https://s2cosmosdb5xlpi3sjpq74e.documents.azure.com:443/"
cosmos_db_master_key = "V3s5RKG9JabjizUl7g11JsC0R7oH4TwpMuOFAN3D3OdaKHCZ80MRrNo21dD3E2zPGHdB0KdcX9ef3Kmqrnfa0g=="
cosmos_db_database = "movies"

if not cosmos_db_endpoint:
  displayHTML("Configuration NOT loaded. Please verify your cosmos_db_endpoint before continuing.")
elif not cosmos_db_master_key:
  displayHTML("Configuration NOT loaded. Please verify your cosmos_db_master_key before continuing.")
elif not cosmos_db_database:
  displayHTML("Configuration NOT loaded. Please verify your cosmos_db_database before continuing.")
else:
  displayHTML("Configuration loaded succesfully.")
# Out:
# Configuration loaded succesfully.
